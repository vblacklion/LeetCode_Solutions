# %%
#Please select one  (Input "s" and Output "p") pair from below: First pair gives True. 
#Second pair gives False and Third pair gives True, Fourth one gives False,
#and the last one gives True
#s = "adhgcdbb"
#p = "a*c?b*"
#s = "adhgcdcb"
#p = "a*c?bkkk"
#s = "adceb"
#p = "*a*b"
s = "cb"
p = "?a"
#s = "aa"
#p = "*"

s_list = []
p_list = []
for item in s:
    s_list.append(item)
for item in p:
    p_list.append(item)
result = 2
def check_the_pattern():
    s = 0
    p = 0
    while p <= len(p_list) or s <= len(s_list):
        if len(p_list) == 2:
            if p_list[p] == "*":
                if p_list[p+1] == s_list[s+1]:
                    print("True")
                    break
                else:
                    print("False")
                    break
            elif p_list[p] == "?":
                if p_list[p+1] == s_list[s+1]:
                    print("True")
                    break
                else:
                    print("False")
                    break
        elif len(p_list) == 1 and p_list[0] == "*":
            print("True")
            break
        elif p_list[p] == s_list[s]:
            p += 1
            s += 1
        elif p_list[p] == "*":
            
            if p == len(p_list)-1 or s == len(s_list)-1:
                print("True")
                break
            elif p_list[p+1] != s_list[s]:
                s += 1
            elif p_list[p+1] == s_list[s]:
                s += 1
                p += 2
                
        elif p_list[p] == "?":
                s += 1
                p += 1
                
        elif s == len(s_list)-1:
            print("True")
            break
        else:
            print("False") 
            break
check_the_pattern()
